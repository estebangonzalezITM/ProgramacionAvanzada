# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **PROGRAMACIÓN AVANZADA**
#
# Notebook creado por los docentes Andres Castro-Ospina y Leonardo Duque-Muñoz, modificado por los docentes Cristian Guarnizo-Lemus y Esteban Gonzalez-Valencia<br>

# %% [markdown]
# # **10. Numpy**
#
# 10.1. Módulos en python
#
#    - 10.1.1. Módulo _builtin_
#    - 10.1.2. Expresión import
#    - 10.1.3. Acceder a un componente contenido en un módulo
#    - 10.1.4. Renombrar módulos y componentes
#
# 10.2. Numpy
#
#    - 10.2.1. Arreglos (arrays)
#    - 10.2.2. Inicialización de arreglos
#    - 10.2.3. Generar arreglos con funciones específicas
#    - 10.2.4. Slicing
#    - 10.2.5. Ejemplo: Slicing con una imagen
#
# 10.3. Funciones básicas y axis
# - 10.3.1. Vectorization
# - 10.3.2. Algebra Lineal
# - 10.3.3. Broadcasting
# - 10.3.4. Ejemplo: Distancia euclidiana

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
# ## **10.1. Módulos en Python**
#
# El lenguaje de programación python cuenta con una gran biblioteca de módulos, los cuales pueden contener funciones, valores, clases y objetos.
#
# Con el siguiente comando se pueden consultar todos los módulos
#
# - `pip list` muestra principalmente paquetes instalados con pip.
# - `pip freeze` muestra esos paquetes en formato **paquete==versión**.
# - `help("modules")` intenta listar módulos importables por Python, incluyendo módulos de la biblioteca estándar como math, os, sys, además de paquetes instalados.

# %%
# !pip list

# %%
# !pip freeze

# %%
help("modules")
#para instalar con pip o con conda

# %% [markdown]
# ### **10.1.1. Módulo \__builtin__**
#
# El módulo denominado `__builtin__` es el lugar donde residen todas las funciones, excepciones y objetos que están disponibles siempre, sin necesidad de importar nada, `range()`, `print()`, `int()`, `str()`, entre muchas otras

# %%
dir(__builtin__)

# %% [markdown]
# Existen muchas funciones que no están cargadas en el entorno por defecto, por tanto es necesario importarla desde los diferentes módulos usando `import`

# %%
sin(3.1416/3)

# %% [markdown]
# ### **10.1.2. Expresión import**
#
# Para importar un módulo, basta con escribir la siguiente sintaxis:
#
# `import <nombreModulo>`

# %%
import math

# %% [markdown]
# Con los comandos `dir` y `help` podemos ver lo que contiene nuestro módulo

# %%
dir(math) #__ __ son métodos mágicos, son usados para operaciones especiales de python

# %%
sin(3.1416/3)
#math.sin(3.1416/3)

# %%
type(math.tanh)

# %%
# Podemos importar funciones incluidas en el módulo importado
print( math.sqrt(16) )

# %%
# Podemos importar constantes incluidos en el módulo importado
print( math.pi )
print( math.e )

# %%
raiz = math.sqrt    # Renombrar una función (NO RECOMENDADO)
print(raiz(16))

e = math.e          # Guardar la constante en una variable
print(e)

# %%
pi

# %%
# Podemos importar constantes o funciones específicas, para simplificar la sintaxis
from math import pi, sin, radians

# %%
pi

# %%
sin(pi/3)

# %%
import numpy

dir(numpy)

# %%
r = numpy.sqrt(16)
print(r)

print(numpy.pi)

# %%
# ?numpy

# %% [markdown]
# ### **10.1.3. Acceder a un componente contenido en un módulo**
#
# Para acceder a un componente que se encuentre contenido en un módulo, basta con usar la sintaxis:
#
# `<modulo>`.`<componente>`

# %%
# ?math.sin

# %%
print(math.sin(math.pi/4))

# %%
print(math.sin(45*math.pi/180))

# %%
print(math.sin(math.radians(45)))

# %%
from math import pi, sin, radians

#print(pi)
print(sin(pi/4))
print(sin(45*pi/180))
print(sin(radians(45)))

# %% [markdown]
# Es posible importar todo el contenido de un módulo, sin embargo no se recomienda.

# %%
from math import *

print(floor(3.02))
print(ceil(3.02))
print(cos(pi/4))

# %% [markdown]
# ### **10.1.4. Renombrar módulos y componentes**

# %% [markdown]
# En python es posible darle otro nombre a un módulo o componente de un módulo, de la siguiente manera:
#
# import `<nombreModulo>` as `<nuevoNombre>`

# %%
import math as m
math.pi

# %%
import math as m
m.pi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **10.2. Numpy**
#
# **NumPy** (Numerical Python) es la librería fundamental para la computación científica en Python, diseñada para manipular datos numéricos con una eficiencia similar a lenguajes como C o Fortran.
#
# **NumPy** es el paquete fundamental para computación numérica con Python https://numpy.org/.

# %% [markdown]
# ### **10.2.1. Arreglos (arrays)**
#
# Un arreglo (array) es una estructura de datos diseñada para almacenar una colección de elementos (generalmente números) del mismo tipo en posiciones de memoria contiguas.
#
# <font color="blue" size=4>**Características fundamentales**</font>
#
# * **Homogeneidad**
#
# A diferencia de una lista de Python (que puede mezclar peras con manzanas), un arreglo exige que todos sus datos sean iguales (por ejemplo, que todos sean float64). Esto permite que la computadora procese los datos mucho más rápido.
#
# * **Eficiencia de memoria**
#
# Al estar "pegados" unos con otros en la RAM, el procesador puede acceder a ellos de forma secuencial sin saltos innecesarios, lo que optimiza el uso de la caché de tu CPU.
#
# * **Dimensiones**
#
# **1D:** Un vector (una fila de datos).
#
# **2D:** Una matriz (filas y columnas).
#
# **3D o más:** Tensores (útiles para datos volumétricos o series temporales).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **10.2.2. Inicialización de arreglos**
#
# La sintaxis es:
#
# `np.array([elemento1, elemento2, elemento3, ...])`

# %%
import numpy as np

A = np.array([1,19,8,-4,5.8])
print(A)

# %%
print(type(A))

# %%
type(A[0])

# %%
for elem in A:
  print(type(elem))

# %%
print(A.dtype)

# %%
B = A.astype(np.uint8)
print(B)
print(type(B))
print(B.dtype)

# %%
B.shape

# %% [markdown]
# `.dtype` (abreviatura de Data Type) **es un atributo fundamental de los arreglos**. Su función principal es indicar el tipo de datos exacto de los elementos almacenados dentro del arreglo.
#
# `.astype()` es el mecanismo de co**nversión de tipos de datos en NumPy**. Permite crear una copia del arreglo con un nuevo tipo de dato.

# %%
l = [1,2,3]
print(l)
print(type(l))

# %%
A = np.array(l)
print(A)
A[2]

# %%
print("Arreglo: ", A)
print("Tipo: ", type(A))
print("Dimensiones del arreglo: ",A.shape)             # imprimimos su tamaño
print("Tipo de dato de los elementos es:", type(A[0]))
print("Tipo de dato del elemento es:", A.dtype)
print("Numero de filas: ", A.shape[0])
# print("Numero de columnas: ", A.shape[1])

# %% [markdown]
# `.shape` **es un atributo fundamental de los arreglos de NumPy**. Devuelve una tupla que indica el tamaño del arreglo en cada una de sus dimensiones.
#
#
# `.shape[0]` indica el tamaño de la primera dimensión; en una matriz 2D corresponde al número de filas.
#
# `.shape[1]` indica el tamaño de la segunda dimensión; en una matriz 2D corresponde al número de columnas.
#
# `.shape[2]`, `.shape[3]`, etc., indican el tamaño de las dimensiones adicionales en arreglos de mayor dimensionalidad.
#
# `.size` indica la cantidad de datos totales en el arreglo.

# %%
# len(A)     # Función interna de python. En arreglos solo devuelve el tamaño del primer eje (filas)
# A.shape    # Devuelve las dimensiones del arreglo
# A.shape[0] # Devuelve el número de filas del arreglo
# A.shape[1] # Devuelve el número de columnas del arreglo
# A.size     # Devuelve la cantidad de datos totales

# %%
A = np.array(l)
print(A)
print(A.shape)

# %%
A = np.expand_dims(A,axis=1)
print(A)
print(A.shape)

# %%
print("Dimensiones del arreglo: ",A.shape)
print("Numero de filas: ", A.shape[0])
print("Numero de columnas: ", A.shape[1])

# %% [markdown]
# En el estado inicial `A` tiene dimensiones `(3,)`, por tanto, es una simple fila de datos sin concepto de "columnas".
#
# Al ejecutar `np.expand_dims(A, axis=1)`, lo que se hace es insertar una nueva dimensión en la posición del índice 1 (las columnas). Ahora es su tamaño es `(3,1)`.
#
# Técnicamente, se acaba de transformar un vector (1D) en una matriz columna (2D).

# %% [markdown]
# * Sumar listas vs Sumar arreglos

# %%
L1 = [1,2,3,4]
L2 = [5,3,2,19]
print(type(L1), type(L2))

# %%
#Sumar estas dos listas
R = L1 + L2
print("Resultado:",R)

# %%
A1 = np.array(L1)
A2 = np.array(L2)
print(A1)
print(A2)

# %%
#Sumar estos dos arreglos
Rn = A1 + A2
print("Resultado:",Rn)

# %% [markdown]
# Si queremos que las listas se comporten como los arreglos, podemos crear una función que sume las listas como su fueran arreglos:

# %%
def SumaLista(L1,L2):
    R = []
    for i in range(len(L1)):
        R.append(L1[i]+L2[i])

    return R

# %%
SumaLista(L1,L2)

# %%
SumaLista([3,5,2,1,2,4,6,2],[1,2,4,56,8,9,1,2])

# %% [markdown]
# Sin embargo, la función `SumaLista` **es mucho menos eficiente que la suma de arreglos**. Para demostrarlo usaremos dos vectores muy grandes y `%timeit`, que se utiliza para medir el tiempo de ejecución de una línea de código de forma precisa y estadística.

# %%
Lista1 = list(range(1000000))
Lista2 = list(range(1000000))

# %%
# %%timeit
RL = SumaLista(Lista1,Lista2)

# %%
Arr1 = np.array(Lista1)
Arr2 = np.array(Lista2)

# %%
# %%timeit
RA = Arr1 + Arr2

# %%
RL = SumaLista(Lista1,Lista2)
RA = Arr1 + Arr2
print(RA)

# %%
RA == RL   # Comparación elemento a elemento

# %%
np.all(RA == RL)    # Comparación entre los dos arreglos

# %% [markdown]
# <a href="https://docs.scipy.org/doc/numpy/reference/arrays.ndarray.html">Consultar Numpy nd-array.</a>

# %% [markdown]
# * **La función** `np.ones`
#
# Es una función de conveniencia de NumPy que se utiliza para inicializar un arreglo nuevo donde todos sus elementos son el número 1.
#
# Sintaxis básica: `np.ones(shape, dtype=None)`
#
# - shape: Las dimensiones del arreglo (un entero para 1D, una tupla para 2D, 3D, etc.).
#
# - dtype: (Opcional) El tipo de dato. Si no se especifica, NumPy usará float64

# %%
help(np.ones)

# %%
O1 = np.ones(5)
print(O1)
O1.dtype

# %%
O2 = np.ones(5, dtype=int)
print(O2)
O2.dtype

# %%
O2 = np.ones(5, dtype=complex)
print(O2)
O2.dtype

# %%
np.ones((4,7), dtype=float)

# %%
np.ones((4,7,3), dtype=float)

# %% [markdown]
# * **La función** `np.zeros`
#
# Es una función de conveniencia de NumPy que se utiliza para inicializar un arreglo nuevo donde todos sus elementos son el número 0.
#
# Sintaxis básica: `np.zeros(shape, dtype=None)`
#
#
# - shape: Las dimensiones del arreglo (un entero para 1D, una tupla para 2D, 3D, etc.).
#
# - dtype: (Opcional) El tipo de dato. Si no se especifica, NumPy usará float64

# %%
help(np.zeros)

# %%
np.zeros(3)

# %%
np.zeros((3,3))

# %%
np.zeros((4,3), dtype=int)

# %%
np.zeros((4,3,5), dtype=int)

# %% [markdown]
# * **La función** `np.full`
#
# Función de NumPy diseñada para inicializar un arreglo de cualquier forma (shape) y rellenarlo con un valor específico definido por el usuario.
#
# Sintaxis básica: `np.full(shape, fill_value, dtype=None)`
#
# - shape: Las dimensiones del arreglo (un entero para 1D, una tupla para 2D, 3D, etc.).
#
# - fill_value: El escalar con el que quieres llenar todo el arreglo (puede ser un número, un booleano o incluso un string).
#
# - dtype: (Opcional) El tipo de dato. Si no se especifica, NumPy lo inferirá del fill_value

# %%
help(np.full)

# %%
np.full(5,25)

# %%
np.full((3,6),255)

# %%
np.full((3,6),1+3j)

# %%
np.full((3,6),1.0)

# %% [markdown]
# * **La función** `np.eye`
#
# La función `np.eye` recibe en el número de filas ($n$).
#
# Sintaxis básica: np.eye($N$, $M$=None, $k$=0, dtype=float)
#
# - $N$: Número de filas.
# - $M$: (Opcional) Número de columnas. Si no se pone, la matriz será cuadrada ($N \times N$).
# - $k$: Índice de la diagonal. 0 es la principal (por defecto), valores positivos suben la diagonal y negativos la bajan.

# %%
help(np.eye)

# %%
np.eye(5,dtype=int)

# %%
np.eye(5,3,dtype=int)

# %%
np.eye(5, k=-1,dtype=int)

# %%
np.eye(5, k=1,dtype=int)

# %%
A = np.ones((3,3))#, dtype = np.int32)
print("Arreglo: \n", A)
print("Tamaño: ", A.shape)
print("Tipo de A: ", type(A))
print("Tipo de elementos en A: ", type(A[0,0]))

B = np.zeros((1,8))
print("\nArreglo: ", B)
print("Size: ", B.shape)
print("Tipo de B: ", type(B))
print("Tipo de elementos en B: ", B.dtype)

U = np.full((5,1),10) # 10*np.ones((5,1))
print("\nArreglo: ", U)
print("Size: ", U.shape)
print("Tipo de B: ", type(U))

# %% [markdown]
# *****
#
# ****

# %% [markdown]
# ### **10.2.3. Generar arreglos con funciones específicas**
#
# Una forma útil de generar arreglos consiste en la utilización de las funciones `__arange__` y `__linspace__`, las cuales permiten generar arreglos secuenciales en un rango de valores. Por otro lado `__random__` genera arreglos con valores aleatorios.

# %% [markdown]
# - ## `__arange__`
#
# Permite crear arreglos de secuencias numéricas, indicando: _<inicio, fin, paso>_.

# %%
list(range(0,10,2))

# %%
help(np.arange)

# %%
A = np.arange(0,10,0.5)
A

# %%
print("Arreglo: ", A)
print("Forma: ", A.shape)
print("Tipo de A: ", type(A))

# %% [markdown]
# ### **Ejemplo:** Calcular el seno(x) para x entre [-10,10]. Resolverlo:
# * Usando listas y con el módulo math

# %%
# Listas y math
import math

# %%
Lista = list(range(-1000,1100))
print(len(Lista))

# %%
# math.sin(Lista)

# %%
# La función seno no admite una lista, por tanto, es necesario calcular el seno elemento por elemento

# %%
# %%timeit
R = []
for i in Lista:
    R.append(math.sin(i))

# %% [markdown]
# ### **Ejemplo:** Calcular el seno(x) para x entre [-10,10]. Resolverlo:
# * Usando arregos con numpy

# %%
Arr = np.arange(-1000,1100)
print(len(Arr))

# %%
# %%timeit
R = np.sin(Arr)

# print(R)

# %%
Arr2 = np.arange(-1000,1100,0.01)
print(len(Arr2))
print(type(Arr2))

R2 = np.sin(Arr2)
print(R)

# %% [markdown]
# * Estos arreglos pueden ser usados, por ejemplo para construir gráficos usando  el módulo `matplotlib`

# %%
Arr = np.arange(-2*np.pi,2*np.pi,0.1)
R = np.cos(Arr)

# %matplotlib inline
plt.plot(Arr,R)

# %% [markdown]
# - ## `__linspace__`
#
# Permite crear arreglos de secuencias numéricas, indicando: _<inicio, fin, número de muestras>_.

# %%
B = np.linspace(0,10,51)
B

# %%
A = np.arange(0,10.2,0.2)
A

# %%
Arr = np.linspace(-2*np.pi,2*np.pi,100)
R = np.cos(Arr)

# %matplotlib inline
plt.plot(Arr,R)

# %%
help(np.linspace)

# %%
A = np.linspace(-10,10,101)
print("Arreglo: ", A)
print("Forma: ", A.shape)

# %%
print(A[2] - A[1])
print(A[80] - A[79])

# %%
np.diff(A)

# %%
x = np.linspace(-10, 10, 500)
Rls = np.sin(1*x)

plt.plot(x,Rls)

# %% [markdown]
# ****

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# *****
#
# - ## `__random__`
#
#
# También es posible generar arreglos de **valores aleatorios** utilizando `numpy.random.rand(dim1, dim2,..., dimn)`
#
# `random.rand` crea un arreglo de las dimensiones especificadas y llenarlo con valores extraídos de una distribución uniforme en el intervalo $[0, 1)$. Esto significa que cualquier número entre 0 (incluido) y 1 (excluido) tiene la misma probabilidad de ser elegido
#
# Sintaxis: `np.random.rand(filas, columnas)`

# %%
help(np.random)

# %%
A = np.random.rand(3,3)
print(A)

# %%
np.random.seed(40)        # Esto garantiza que aunque los números parezcan aleatorios, serán exactamente los mismos cada vez que se ejecuta el script

A1 = np.random.rand(2,5)
print(A1)

# %%
print(A1.shape)

# %% [markdown]
# `random.randint` genera números enteros en un rango inferior (low) y el superior (high)
#
# Sintaxis: `np.random.randint(low, high, size=(filas, columnas)).`
#
# *   List item
# *   List item

# %%
import numpy as np

# %%
# Cuando solo se le entregan dos números antes del size, NumPy los toma como el límite inferior y superior
A2 = np.random.randint(5,15,size=(10))
print(A2)

# %%
# Cuando solo se le entrega un número antes del size, NumPy lo toma como el límite superior. El límite inferior (low) por defecto es 0.
# np.random.seed(42)
A3 = np.random.randint(70,size=(3,10))
print(A3)

# %%
# print(np.random.random_integers(10, size=(1,5)))

# %% [markdown]
# Por otro lado encontramos `random.permutation`, cuyo comportamiento varía en función del tipo de argumento que se le entrega
# - Si se le entrega un entero crea una secuencia de 0 hasta *n-1* y la desordena.Devuelve una copia de la secuencia permutada.
# - Si le entrega un arreglo toma los elementos del arreglo y los reordena al azar.
#
# Sintaxis: `np.random.permutation(n).`

# %%
A4 = np.random.permutation(10) #Permutar números del 0 al 9
print(A4)

# %%
A5 = np.random.permutation(A4)
print(A5)

# %%
A3 = np.random.randint(70,size=(3,10))
print(A3,'\n')

A5 = np.random.permutation(A3)
print(A5)

# %% [markdown]
# La función `np.resize()` se utiliza para crear un nuevo arreglo con una forma específica.
# * `np.resize` es capaz de "inventar" o repetir datos si el tamaño de destino es mayor que el original.
#
#
# Sintaxis: `ny.resize(array, new_shape).`

# %%
A5 = np.random.permutation(A4)
print(A5)

B = np.resize(A5,(10,3))
print(B)

# %% [markdown]
# * Limitar cuántos decimales mostrar

# %%
AA = np.random.rand(2,2)
print(AA)

# %%
np.set_printoptions(precision=2)
print('\n',AA)
print (AA[1,1])

# %%
# arreglo de (1,5) con números aleatorios, pero entre 0 y 10

A = 10*np.random.rand(1,5)
A

# %%
print(np.random.rand(5,5))

# %%
print(np.random.randint(10,20,(5,5)))

# %% [markdown]
# ## **Ejemplo:**
#
# La definición formal de un número aleatorio en un rango es: $(b-a)*rand + a$. Utilicemos esta definición para crear una matriz aleatoria cuyos elementos tengan valores entre 5 y 15.

# %%
import random
#seed o semilla
M = np.zeros([3,5])

a = 5
b = 15

for i in range(M.shape[0]):
    for j in range(M.shape[1]):
        M[i,j] = (b-a)*random.random()+a       # random.random() genera un único valor aleatorio
print(M)

# %%
M2 = (b-a)*np.random.rand(4,4)+a
print(M)

# %% [markdown]
# ***
# ***
# ### **10.2.4. Slicing**
#
# Como slicing se conoce a la posibilidad de obtener porciones de un arreglo utilizando notación de índices.

# %%
string = "Hola LPW"

print(string[5:10])

#print(string[-3:])

# %%
# A = np.random.rand(5,6)
A = np.random.permutation(30).reshape(5,6)
print('A =', A,'\n')
print(A.shape)

# %%
A

# %%
print(A[2][3])

# %%
print(A[2,3])

# %%
print(A[1][2])
print(A[1,2])

# %%
print(A[3][1])
print(A[3,1])

# %%
A

# %%
print(A[1][:])
print(A[1,:])
# print(type(A[1,:]))
# print(A[:,2].shape)

# %%
A

# %%
print(A[1,3:])

# %%
print(A[1,:3])

# %%
A

# %%
print(A[1:,3])

# %%
A

# %%
print(A[:,3])
print(A[3:,3])
print(A[:3,3])

# %%
A

# %%
print(A[2,2:4])

# %%
print(A[1:3,3])

# %%
A

# %%
print(A[2:,2:5])

# %%
# print(A[:2,:2])
# print(A[1:4,1:4])

# %%
print(np.expand_dims(A[:,1],axis = 1))
# print(A[:,1])
# print(A[:,1].shape)

# %%
A

# %%
A_ = A[:,:, np.newaxis]
A_

# %%
print(A_.shape)

# %%
print(A[:,2].reshape(5,1))

# %%
A_ = A[:,:, np.newaxis]
print(A_.shape)
print(A[:,2].reshape(5,1))

print(A[2:,2:])
# print(A[:2,:2])
# print(A[1:4,1:4])

print(A[2:,[3,5]])

# %%
A

# %%
print(A[[0,2,4],[1,3,5]])

# %% [markdown]
# La función `np.ix_` crea dos estructuras que, al usarse juntas, obligan a NumPy a buscar todas las combinaciones posibles de esas filas y columnas.

# %%
indx = np.ix_([0,2,4],[1,3,5])
print(A[indx])

# %% [markdown]
# Alternativa (mas 'mánual')

# %%
print(A[np.array([[0,2,4]]).T,np.array([[1,3,5]])])

# %%
print(A[[0,0,0,2,2,2,4,4,4],[1,3,5,1,3,5,1,3,5]])

# %%
print(A[[0,0,0,2,2,2,4,4,4],[1,3,5,1,3,5,1,3,5]].reshape(3,3))

# %%
R1 = A[0,:]
R2 = A[:,0]
R3 = A[1:4, 1:4]

print("Primera fila del arreglo: ", R1)
print("Primera columna del arreglo: ", R2)
print("Arreglo de 3x3 desde la fila 1 a la fila 3 y desde la columna 1 a la columna 3\n", R3)

# %%
R1[0] = 99999
R1

# %%
R3[0,0] = -99
R3

# %%
A

# %%
B = A.copy()
B

# %% [markdown]
# ### **10.2.5. Ejemplo: Slicing con una imagen**

# %%
# !wget https://cdn.colombia.com/images/v2/colombia-info/informacion/informacion-800.webp

im = plt.imread('./informacion-800.webp')

# %%
# !wget https://www.plazapublica.com.gt/sites/default/files/trabajadoras_domesticas_14.webp

# im = plt.imread('./trabajadoras_domesticas_14.webp')

# %%
type(im)

# %%
im.shape #pixeles (PICture ELement)

# %%
# print(im)

# %%
im.dtype

# %%
plt.imshow(im)

# %%
#plt.imshow(im[:,:,0])
plt.imshow(im[:,:,2], cmap='gray')

# %%
plt.imshow(im[::-1,:])

# %%
plt.imshow(im[:,::-1])

# %%
plt.imshow(im)

# %%
plt.imshow(im[40:50,140:150])

# %%
plt.imshow(im[100:,40:230])

# %%
plt.imshow(im)

# %%
plt.imshow(im[1::8, 1::8])
print(im[1::8, 1::8].shape)

# %%
plt.imshow(im[100:,40:230,1])

# %%
im.shape

# %% [markdown]
# ******
# <hr>
#
#
# ## **10.3. Funciones básicas y axis**
#
# La mayoría de operaciones útiles al trabajar con arreglos n-dimensionales están implementadas en la librería Numpy, por ejemplo: sum, std, transpose, power, entre otras.
#
# Analicemos el siguiente ejemplo de una sumatoria.

# %%
Lista = list(range(1000000))
len(Lista)

# %%
#Lista[-1]

# %%
Arr = np.arange(1000000)
Arr.shape

# %%
# %%timeit
sum(Lista)

# %%
# %%timeit
sum(Arr)

# %%
# %%timeit
np.sum(Arr)

# %%
A = np.random.rand(3,5,4)
print(A)

# %%
A.shape # El atributo shape retorna las dimensiones de la tupla

# %% [markdown]
# * La operación `np.sum(A, axis=0)` "colapsar" o "aplastar" esa primera dimensión sumando sus elementos.

# %%
# %%timeit
B = np.sum(A,axis=0)
print(B)
B.shape

# %%
np.sum(A,axis=1)

# %%
for k in range(A.shape[1]):
  print(A[:,k,:],'\n')
#A.shape[1]

# %%
np.sum(A,axis=2)

# %%
# Alternativa "manual"
suma = 0

for i in range(A.shape[0]):
    suma += A[i,:,:]

print(suma)

# %%
A

# %%
np.sum(A,axis=1).reshape(6,2)

# %%
np.sum(A,axis=1)

# %%
suma = 0
for i in range(A.shape[1]):
    suma = suma + A[:,i]

suma = np.expand_dims(suma, axis=1)
print(suma)

# %%
A = np.random.rand(300,500)
print(A)

# %%
# %%timeit
suma_ = np.sum(A,axis=0)

# %%
# %%timeit
suma = 0
for i in range(A.shape[1]):
    suma = suma + A[:,i]

suma = np.expand_dims(suma, axis=1)
# print(suma)

# %% [markdown]
# * La mayoría de funciones que operan arreglos n-dimensionales, cuentan con un parámetro __axis__ que especifica la dimensión sobre la cuál se realiza la operación.
#
# Analicemos el siguiente ejemplo:

# %%
np.random.seed(2) #fijemos la semilla aleatoria para obtener el mismo resultado

a = 1
b = 10
M = (b-a)*np.random.rand(4,5)+a #Generemos un arreglo numerico aleatorio de dimension 4x5, entre 1 y 10
print(M)

# %% [markdown]
# **Sumemos las filas** de la matriz anterior, utilizando el parámetro axis de la función sum:

# %%
result1 = np.sum(M, axis=1)
result1

# %% [markdown]
# **Sumemos las columnas** de la matriz anterior, utilizando el parámetro axis de la función sum:

# %%
result = np.sum(M, axis=0)
result

# %%
result.reshape(5,1)

# %% [markdown]
# <hr>
#
# ## Analicemos
#
# Si tengo un arreglo A de dimension MxNxL y aplico np.sum(A, axis=1), ¿de qué dimensión es el arreglo resultante?

# %%
K = np.random.rand(3,4,5)
print(K)
print(K.shape)

# %%
R = np.sum(K, axis=1)
print(R.shape)

# %% [markdown]
# * `Matplotlib` tiene una enorme variedad de mapas de colores (`cmaps`) diseñados para diferentes tipos de datos. No todos sirven para lo mismo: algunos son mejores para resaltar detalles, otros para datos que van de negativo a positivo, y otros para categoría

# %%
from matplotlib import colormaps
print(list(colormaps))

# %%
plt.imshow(im)
print(im.shape)
G = np.mean(im, axis = 2)
plt.imshow(G, cmap='plasma')
print(G.shape)

# %%
plt.imshow(np.abs(G-255), cmap='plasma')

# %% [markdown]
# ****
# ****

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### **10.3.1. Vectorización**
#
# Numpy contiene las **versiones vectorizadas** de las funciones de la librería math (**funciones escalares**), por ejemplo:
# - math.sin --> numpy.sin
# - math.exp --> numpy.exp
#
# A diferencia de las funciones de la librería math, las versiones vectorizadas pueden recibir arreglos n-dimensionales como argumentos.

# %%
Lista = list(range(1000000))
print(len(Lista))

Arreglo = np.arange(0,1000000,1)
print(np.size(Arreglo))

# %%
# %%timeit
R1 = []
for i in Lista:
    R1.append(math.sin(i))

# %%
# %%timeit
R2 = np.sin(Arreglo)

# %%
R1 = []
for i in Lista:
    R1.append(math.sin(i))

R2 = np.sin(Arreglo)

np.all(R1 == R2)

# %% [markdown]
# * La función sigmoide es una función matemática con forma de “S” que se usa mucho en áreas como el aprendizaje automático, la ciencia de datos, estadística y biología.
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}
# $$
# Esta función no está incluida en los módulos math o numpy. Por tanto, vamos a crear la función sigmoide:

# %%
def sigmoid(z):
    return 1. / (1. + math.exp(-z))

# %%
x = np.linspace(-10,10,21)
print(x)
print(x.shape)

# %%
sigmoid(x)

# %%
R = []
for i in x:
    R.append(sigmoid(i))
R

# %%
plt.plot(x,R)
plt.grid()
plt.xlim([-5,5])

# %% [markdown]
# * Una funcion escalar puede vectorizarse usando `np.vectorize`.
# * Esta herramienta de conveniencia que transforma una función que acepta un solo escalar en una que puede aceptar un array de NumPy
# * Sin embargo, es vital entender que `np.vectorize` no es verdadera vectorización a nivel de hardware.

# %%
help(np.vectorize)

# %%
sigmoid_vec = np.vectorize(sigmoid)

# %%
type(sigmoid_vec)

# %%
print(x,'\n')
R2 = sigmoid_vec(x)
R2

# %%
plt.plot(x,R,'k-',x,R2,'r--')
plt.grid()
plt.xlim([-5,5])

# %% [markdown]
# Evaluemos la eficiencia de estas dos funciones

# %%
x2 = np.linspace(-10,10,1000001)

# %%
# %%timeit
R = []
for i in x2:
    R.append(sigmoid(i))

# %%
# %%timeit
R2 = sigmoid_vec(x2)

# %% [markdown]
# * Ahora creemos una verdadera funcion sigmoide vectorizada

# %%
def sigmoide_np(z):
    return 1. / (1. + np.exp(-z))

# %%
# %%timeit
y = sigmoide_np(x2)

# %%
R3 = sigmoide_np(x)

plt.plot(x,R,'b-',x,R2,'r--',x,R3,'g*:')
plt.grid()
plt.xlim([-5,5])

# %% [markdown]
# **NOTA 1:**
#
# Como alternativa al ciclo for, puede usarse `map(sigmoid,z)`, que toma la función escalar `sigmoid` y la aplica uno por uno a cada elemento dentro de `x` como si estuviera iterando un ciclo. Luego `list()` guarda el resultado en una lista

# %%
y2 = list(map(sigmoid, x))
y2

# %%
# %%timeit
y2 = list(map(sigmoid, x2))

# %% [markdown]
# **NOTA 2:**
#
# En Python, `lambda` es una palabra clave que sirve para crear funciones de una sola línea. Se usan cuando necesitas una función rápida y sencilla que no vas a reutilizar mucho en otras partes del código.

# %%
SigmoideLambda = lambda z: 1. / (1. + np.exp(-z))

# %%
# %%timeit
SL = SigmoideLambda(x2)

# %%
SL = SigmoideLambda(x)
plt.plot(x,SL)
plt.grid()

# %% [markdown]
# ****

# %% [markdown]
# ### **10.3.2. Algebra Lineal**

# %%
np.random.seed(0)

A = np.random.rand(10000000)
B = np.random.rand(10000000)

# %%
print(A.shape)
print(B.shape)

# %%
C = A + B
C

# %%
C1 = A - B
C1

# %% [markdown]
# * Otra forma de saber cuanto demora la ejecución de una celda es usando `time()`.
#
# *Return the current time in seconds since the Epoch.
# Fractions of a second may be present if the system clock provides them.*

# %%
#time.time?

# %%
import time

# %%
time.time()

# %% [markdown]
# * ¿Cómo medir el tiempo entre dos momentos?

# %%
tic = time.time()    #  Tiempo de referencia para empezar a medir
# Parte del cógido que quiero evaluar
time.sleep(1)        # Pausa de 1 s
toc = time.time()    #  Tiempo final que tardo en ejecutarse el código

print("Elapsed time:", (toc-tic),'s')

# %%
tic = time.time()

C = 0

for i in range(len(A)):
    C += A[i]*B[i]

toc = time.time()

print('C =',C)
print("Elapsed time:", (toc-tic),'s')

# %%
# CUIDADO: No es lo mismo multiplicar dos vectores que dos matrices
np.random.seed(0)
A = np.random.randint(20,size=(4,4))
B = np.random.randint(20,size=(4,4))
A

# %%
D = 0

tic = time.time()

#D = np.dot(A,B)
#D = np.matmul(A,B)
#D = A@B
D = A.T@B

toc = time.time()

print('D =',D)
print("Elapsed time: ", (toc-tic))

# %%
def prodpun(A,B):
    suma = 0
    for i in range(10000000):
        suma += A[i]*B[i]
    return suma

# %%
# %timeit np.dot(A,B)
# %timeit prodpun(A,B)

# %%
# %timeit map(prodpun,A,B)

# %%
print(map(prodpun,A,B))

# %% [markdown]
# ### **10.3.3. Broadcasting**
# El **broadcasting** es una de las características más potentes de NumPy. Es lo que permite realizar operaciones aritméticas entre arrays que tienen diferentes formas (shapes).
#
# Normalmente, para operar con dos matrices, estas tendrían que ser del mismo tamaño. El **broadcasting** rompe esa regla siguiendo un conjunto de normas lógicas para "estirar" el array más pequeño de modo que coincida con el más grande.

# %%
np.random.seed(2)

A0 = np.random.randint(0,4,(4,3))
print(A0)
print(f"Tamaño de A0= {A0.shape}")

# %%
A1 = np.ones((4,1), dtype= int)

print(A1)
print(f"Tamaño de A1= {A1.shape}")

# %%
print(A0 + A1)

# %% [markdown]
# Para saber si dos arrays son compatibles, NumPy compara sus dimensiones de derecha a izquierda (empezando por la última). Dos dimensiones son compatibles si:
#
#  - Son iguales.
#
# - Una de ellas es 1.

# %%
np.random.seed(2)

Ak = np.random.randint(0,4,(5,4))
print(Ak)
print(f"\nTamaño de Ak = {Ak.shape}\n")
media_fila = np.mean(Ak, axis=1)
print(media_fila)
print(f"\nTamaño de media_fila = {media_fila.shape}")

# %%
Akm = Ak - media_fila
print(media_fila)
print(Akm)

# %% [markdown]
# <hr>
#
# ### **10.3.4. Ejemplo: Distancia euclidiana**
#
# Supongamos dos arreglos A y B de tamaño $m \times 2$, donde $m$ es un número de puntos y $2$ es la dimensión de los puntos, es decir, 2D para este ejemplo.
#
# Vectorizar la distancia Euclídea entre cada punto 2D en A y su correspondiente punto 2D en B. El resultado debe ser un arreglo de dimensión $m$.

# %%
np.random.seed(2)

m = 5000

A = np.random.randint(10, size=(m,2))
B = np.random.randint(10, size=(m,2))
#B = np.random.rand(m, 2)

# %%
A

# %%
B

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(3,3))
plt.plot(A[:,0], A[:,1], 'r*')
plt.plot(B[:,0], B[:,1], 'b*')
plt.show()

# %% [markdown]
# * Crear una función **escalar** para calcular la distancia entre dos puntos:
#
# $distAB = \sqrt{ (x_2-x_1)^2 +(y_2-y_1)^2} $

# %%
def distAB(ax,ay,bx,by):
  return math.sqrt((ax-bx)**2+(ay-by)**2)

# %%
R = []
for k in range(A.shape[0]):
  R.append(distAB(A[k,0],A[k,1],B[k,0],B[k,1]))
R

# %% [markdown]
# * Vectorizar la función `distAB`:

# %%
distAB_v = np.vectorize(distAB)

# %%
# %%timeit
distAB_v(A[:,0],A[:,1],B[:,0],B[:,1])

# %% [markdown]
# * Construir la función vectorizada `distAB_np`:

# %%
def distAB_np(ax,ay,bx,by):
  return np.sqrt((ax-bx)**2+(ay-by)**2)

# %%
# %%timeit
distAB_np(A[:,0],A[:,1],B[:,0],B[:,1])
